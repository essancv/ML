# %%
import numpy as np
from h5py import File
import scipy.io #Used to load the OCTAVE *.mat files
import numpy as np
import sys
sys.path.append ('../src')
from NeuralNetwork import NNClassifier
from ML_utils import softmax,sigmoid,UTIL_formatY,backward_prop,backpropagation
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import multilabel_confusion_matrix,classification_report

# %%
MNIST_data = File("data/MNISTdata.hdf5", 'r')
x_train = np.float32(MNIST_data['x_train'][:])
y_train = np.int32(np.array(MNIST_data['y_train'][:, 0])).reshape(-1, 1)
x_test  = np.float32(MNIST_data['x_test'][:])
y_test  = np.int32(np.array(MNIST_data['y_test'][:, 0])).reshape(-1, 1)
MNIST_data.close()

# stack together for next step
X = np.vstack((x_train, x_test))
print (X.shape)
y = np.vstack((y_train, y_test))
print (y.shape)

# one-hot encoding
digits = 10
examples = y.shape[0]
y = y.reshape(1, examples)
Y_new = np.eye(digits)[y.astype('int32')]
Y_new = Y_new.T.reshape(digits, examples)


# number of training set
m = 60000
m_test = X.shape[0] - m
X_train, X_test = X[:m].T, X[m:].T
Y_train, Y_test = Y_new[:, :m], Y_new[:, m:]


# shuffle training set
shuffle_index = np.random.permutation(m)
X_train, Y_train = X_train[:, shuffle_index], Y_train[:, shuffle_index]
# Out:
# (70000, 784)
# (70000, 1)

# %%
opt = {'n_h':64,'n_x':784,'epochs':10, 'batch_size':64 , 'beta':0.9,'lr':0.5}

# initialization
params = {"W1": np.random.randn(opt['n_h'], opt['n_x']) * np.sqrt(1. / opt['n_x']),
          "b1": np.zeros((opt['n_h'], 1)) * np.sqrt(1. / opt['n_x']),
          "W2": np.random.randn(digits, opt['n_h']) * np.sqrt(1. / opt['n_h']),
          "b2": np.zeros((digits, 1)) * np.sqrt(1. / opt['n_h'])}
print (params['W1'].shape)
print (params['b1'].shape)
print (params['W2'].shape)
print (params['b2'].shape)
# Out:
# (64, 784)
# (64, 1)
# (10, 64)
# (10, 1)

# %%
T1 = np.copy(np.hstack(( params['b1'],params['W1'])))
print (T1.shape)
T2 = np.copy(np.hstack(( params['b2'],params['W2'],)))
print (T2.shape)
# Out:
# (64, 785)
# (10, 65)

# %%
nn_config={'n_a1':784,'n_a2':64,'n_a3':10 }   # Configuración de red NN , input layer , hidder layers , output layer
sgd_dict =   {'steps':10,'learning_rate':0.5,'mini_batch_size':2**8}
opt_dict =   {'maxiter':100,'algorithm' : 'TNC'}
activ = {'activation_a2':sigmoid,'activation_a3':softmax}
method = 'miniBatchGD'
nn = NNClassifier(optimization=method,bias=True,nn_config=nn_config,activ=activ,debug=False,kargs=sgd_dict)
print (nn.thetas['Theta1'].shape)
print (nn.thetas['Theta2'].shape)
nn.thetas['Theta1'] = T1
nn.thetas['Theta2'] = T2
# Out:
# (64, 785)
# (10, 65)

# %%
def sigmoid(z):
    """
    sigmoid activation function.

    inputs: z
    outputs: sigmoid(z)
    """
    s = 1. / (1. + np.exp(-z))
    return s
def compute_loss(Y, Y_hat):
    """
    compute loss function
    """
    L_sum = np.sum(np.multiply(Y, np.log(Y_hat)))
    m = Y.shape[1]
    L = -(1./m) * L_sum

    return L
def feed_forward(X, params):
    """
    feed forward network: 2 - layer neural net

    inputs:
        params: dictionay a dictionary contains all the weights and biases

    return:
        cache: dictionay a dictionary contains all the fully connected units and activations
    """
    cache = {}

    # Z1 = W1.dot(x) + b1
    cache["Z1"] = np.matmul(params["W1"], X) + params["b1"]
    
    # A1 = sigmoid(Z1)
    cache["A1"] = sigmoid(cache["Z1"])

    # Z2 = W2.dot(A1) + b2
    cache["Z2"] = np.matmul(params["W2"], cache["A1"]) + params["b2"]

    # A2 = softmax(Z2)
    cache["A2"] = np.exp(cache["Z2"]) / np.sum(np.exp(cache["Z2"]), axis=0)
#    cache["A2"] = sigmoid(cache["Z2"])

    return cache
def back_propagate(X, Y, params, cache, m_batch):
    """
    back propagation

    inputs:
        params: dictionay a dictionary contains all the weights and biases
        cache: dictionay a dictionary contains all the fully connected units and activations

    return:
        grads: dictionay a dictionary contains the gradients of corresponding weights and biases
    """
    # error at last layer
    dZ2 = cache["A2"] - Y

    # gradients at last layer (Py2 need 1. to transform to float)
    dW2 = (1. / m_batch) * np.matmul(dZ2, cache["A1"].T)
    db2 = (1. / m_batch) * np.sum(dZ2, axis=1, keepdims=True)

    # back propgate through first layer
    dA1 = np.matmul(params["W2"].T, dZ2)
    dZ1 = dA1 * sigmoid(cache["Z1"]) * (1 - sigmoid(cache["Z1"]))

    # gradients at first layer (Py2 need 1. to transform to float)
    dW1 = (1. / m_batch) * np.matmul(dZ1, X.T)
    db1 = (1. / m_batch) * np.sum(dZ1, axis=1, keepdims=True)

    grads = {"dW1": dW1, "db1": db1, "dW2": dW2, "db2": db2}

    return grads

# %%
batches=10
for i in range(opt['epochs']):

    # shuffle training set
    permutation = np.random.permutation(X_train.shape[1])
    X_train_shuffled = X_train[:, permutation]
    Y_train_shuffled = Y_train[:, permutation]

    for j in range(batches):
        #np.testing.assert_allclose (params['W1'],nn.thetas['Theta1'][:,1:])
        #np.testing.assert_allclose (params['W2'],nn.thetas['Theta2'][:,1:])
        #np.testing.assert_allclose (params['b1'],nn.thetas['Theta1'][:,0:1])
        #np.testing.assert_allclose (params['b2'],nn.thetas['Theta2'][:,0:1])

        # get mini-batch
        begin = j * opt['batch_size']
        end = min(begin + opt['batch_size'], X_train.shape[1] - 1)
        X = X_train_shuffled[:, begin:end]
        Y = Y_train_shuffled[:, begin:end]
        m_batch = end - begin

        nnX_train = np.copy(X.reshape (X.shape[1],X.shape[0]))
        nnY_train = np.copy(Y.reshape (Y.shape[1],Y.shape[0]))

        # forward and backward
        cache = feed_forward(X, params)
        #prediction,nncache = nn.forward_prop (X.T)
        #np.testing.assert_allclose (prediction.T,cache['A2'])
        grads = back_propagate(X, Y, params, cache, m_batch)
        #delta,nngrads = nn.backward_prop (X.T,Y.T)
        #np.testing.assert_allclose (grads['dW1'],nngrads['grad1'][:,1:])
        #np.testing.assert_allclose (grads['dW2'],nngrads['grad2'][:,1:])
        #np.testing.assert_allclose (grads['db1'],nngrads['grad1'][:,0:1])
        #np.testing.assert_allclose (grads['db2'],nngrads['grad2'][:,0:1])

        # with momentum (optional)
        dW1 = grads ['dW1']
        db1 = grads ['db1']
        dW2 = grads ['dW2']
        db2 = grads ['db2']
        
        dW1 = (opt['beta'] * dW1 + (1. - opt['beta']) * grads["dW1"])
        db1 = (opt['beta'] * db1 + (1. - opt['beta']) * grads["db1"])
        dW2 = (opt['beta'] * dW2 + (1. - opt['beta']) * grads["dW2"])
        db2 = (opt['beta'] * db2 + (1. - opt['beta']) * grads["db2"])
    
        # gradient descent
        params["W1"] = params["W1"] - opt['lr'] * dW1
        params["b1"] = params["b1"] - opt['lr'] * db1
        params["W2"] = params["W2"] - opt['lr'] * dW2
        params["b2"] = params["b2"] - opt['lr'] * db2
        #nn._updateThetas (nngrads,opt['lr'])
        #np.testing.assert_allclose (params['W1'],nn.thetas['Theta1'][:,1:])
        
    # forward pass on training set
    cache = feed_forward(X_train, params)
    #prediction,_ = nn.forward_prop (X_train.T)
    train_loss = compute_loss(Y_train, cache["A2"])
    #cost = nn.costFunction (X_train.T,Y_train.T)
    # forward pass on test set
    cache = feed_forward(X_test, params)
    test_loss = compute_loss(Y_test, cache["A2"])
    print("Epoch {}: training loss = {}, test loss = {}".format(
        i + 1, train_loss, test_loss))
# Out:
# Epoch 1: training loss = 1.970743261533071, test loss = 1.9629573743205424
# Epoch 2: training loss = 1.5994230516340866, test loss = 1.5875651002471802
# Epoch 3: training loss = 1.2855953514193994, test loss = 1.2678200435568923
# Epoch 4: training loss = 1.0735109749297258, test loss = 1.0567940953373172
# Epoch 5: training loss = 0.9041955996535975, test loss = 0.8853720079015203
# Epoch 6: training loss = 0.8177456112023864, test loss = 0.7986463499783694
# Epoch 7: training loss = 0.7207538807386803, test loss = 0.7001803659369845
# Epoch 8: training loss = 0.6841058784790693, test loss = 0.6695612783391528
# Epoch 9: training loss = 0.6166655116708453, test loss = 0.6008955548506377
# Epoch 10: training loss = 0.5808964832872017, test loss = 0.5640612607930451

# %%
from sklearn.metrics import multilabel_confusion_matrix,classification_report
result = feed_forward (X_test,params)
prediction = np.argmax(result['A2'],axis=0)
print (prediction[0:5])

print(f"Classification report for classifier :\n"
      f"{classification_report(y_test,prediction)}\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ed0a5abe40a8> in <module>
#       1 from sklearn.metrics import multilabel_confusion_matrix,classification_report
# ----> 2 result = feed_forward (X_test,params)
#       3 prediction = np.argmax(result['A2'],axis=0)
#       4 print (prediction[0:5])
#       5
#
# NameError: name 'feed_forward' is not defined

# %%
nn_config={'n_a1':784,'n_a2':64,'n_a3':10 }   # Configuración de red NN , input layer , hidder layers , output layer
sgd_dict =   {'steps':10,'learning_rate':0.5,'mini_batch_size':2**8}
opt_dict =   {'maxiter':100,'algorithm' : 'TNC'}
activ = {'activation_a2':sigmoid,'activation_a3':softmax}
method = 'miniBatchGD'

nn = NNClassifier(optimization=method,bias=True,nn_config=nn_config,activ=activ,debug=False,kargs=sgd_dict)
costs = nn.optimize (X_train.T,Y_train.T,l2_lambda=0.0)
prediction,_ = nn.forward_prop (X_train.T)
result = np.argmax(prediction,axis=1).reshape(-1,1)
y = np.argmax(Y_train.T,axis=1).reshape(-1,1)

accuracy = np.mean(y==result) * 100
print ('Trainig set accuracy :' , accuracy  )

test_predicted,_ = nn.forward_prop (X_test.T)
result = np.argmax(test_predicted,axis=1).reshape(-1,1)
y = np.argmax(Y_test.T,axis=1).reshape(-1,1)
accuracy = np.mean(y==result) * 100
print ('Test set accuracy :' , accuracy  )

print(f"Classification report for classifier {nn}:\n"
      f"{classification_report(y,result)}\n")
# Out:
# LR = 0.5:  30%|█████████████████████▉                                                   | 3/10 [00:09<00:21,  3.14s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-6beb4787d5fb> in <module>
#       6
#       7 nn = NNClassifier(optimization=method,bias=True,nn_config=nn_config,activ=activ,debug=False,kargs=sgd_dict)
# ----> 8 costs = nn.optimize (X_train.T,Y_train.T,l2_lambda=0.0)
#       9 prediction,_ = nn.forward_prop (X_train.T)
#      10 result = np.argmax(prediction,axis=1).reshape(-1,1)
#
# C:\Tutoriales\ia\MachineLearning\ML\src\NeuralNetwork.py in optimize(self, X, Y, l2_lambda)
#     193             return self._stochasticGD (X,Y,l2_lambda)
#     194         elif self.optimization == "miniBatchGD":
# --> 195             return self._miniBatchGD (X,Y,l2_lambda)
#     196         else:
#     197             raise NotImplementedError ("Valid methods are :'SGD','Optimize','miniBatchGD'")
#
# C:\Tutoriales\ia\MachineLearning\ML\src\NeuralNetwork.py in _miniBatchGD(self, X, Y, l2_lambda)
#     179
#     180                 costs.append (cost)
# --> 181                 delta,grads= self.backward_prop (miniBatchX.T,miniBatchY.T,l2_lambda)
#     182
#     183                 self._updateThetas (grads,lr)
#
# C:\Tutoriales\ia\MachineLearning\ML\src\NeuralNetwork.py in backward_prop(self, X, Y, l2_lambda)
#      84         X = self._insertBias (np.copy(X))
#      85         m = X.shape [0]
# ---> 86         prediction,cache = self.forward_prop (X)
#      87         prediction = np.array (prediction)
#      88         delta = {}
#
# C:\Tutoriales\ia\MachineLearning\ML\src\NeuralNetwork.py in forward_prop(self, X)
#      71
#      72         for i in range(2,self.n_layers + 1):
# ---> 73             zi = np.dot (ai , self.thetas['Theta'+str(i-1)].T )
#      74 #            ai = sigmoid (zi)
#      75             ai = self.activ ['activation_a'+str(i)](zi)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
nn_config={'n_a1':784,'n_a2':128 ,'n_a3':64,'n_a4':10 }   # Configuración de red NN , input layer , hidder layers , output layer
sgd_dict =   {'steps':10,'learning_rate':0.5,'mini_batch_size':2**8}
opt_dict =   {'maxiter':100,'algorithm' : 'TNC'}
activ = {'activation_a2':sigmoid,'activation_a3':sigmoid,'activation_a4':softmax}
method = 'miniBatchGD'

nn = NNClassifier(optimization=method,bias=True,nn_config=nn_config,activ=activ,debug=False,kargs=sgd_dict)
costs = nn.optimize (X_train.T,Y_train.T,l2_lambda=1.0)
prediction,_ = nn.forward_prop (X_train.T)
result = np.argmax(prediction,axis=1).reshape(-1,1)
y = np.argmax(Y_train.T,axis=1).reshape(-1,1)

accuracy = np.mean(y==result) * 100
print ('Trainig set accuracy :' , accuracy  )

test_predicted,_ = nn.forward_prop (X_test.T)
result = np.argmax(test_predicted,axis=1).reshape(-1,1)
y = np.argmax(Y_test.T,axis=1).reshape(-1,1)
accuracy = np.mean(y==result) * 100
print ('Test set accuracy :' , accuracy  )

print(f"Classification report for classifier {nn}:\n"
      f"{classification_report(y,result)}\n")
# Out:
# LR = 0.5:   0%|                                                                                 | 0/10 [00:00<?, ?it/s]
# 0.009658463671320509
# costFunction, regularization value 1.0267061398988189 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009596299146942835
# costFunction, regularization value 1.0226846921182635 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009560872827665639
# costFunction, regularization value 1.0186613030022602 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009516077554699066
# costFunction, regularization value 1.014677687619116 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.00949838678242525
# costFunction, regularization value 1.0107622800672496 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009446138626667896
# costFunction, regularization value 1.0068130635718087 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009405532453783932
# costFunction, regularization value 1.002886216336141 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009377119777779613
# costFunction, regularization value 0.9990131977479544 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009340568569492374
# costFunction, regularization value 0.9951593750329258 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009296446334126093
# costFunction, regularization value 0.9912593671524537 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009282286146139134
# costFunction, regularization value 0.9874801956589357 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009226381686155343
# costFunction, regularization value 0.9836149445892555 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009193070304625076
# costFunction, regularization value 0.9798037981981874 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009178523624890581
# costFunction, regularization value 0.9760525029746511 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.00912658201229724
# costFunction, regularization value 0.9722599939943606 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009093732599228917
# costFunction, regularization value 0.9685446527839111 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.00906413130438534
# costFunction, regularization value 0.9648276157153736 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009041058878606624
# costFunction, regularization value 0.9611315646062916 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009000929943032013
# costFunction, regularization value 0.9574745974164725 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.00897654083946963
# costFunction, regularization value 0.9538565540341089 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008936695009150316
# costFunction, regularization value 0.950130413541095 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008917033701833152
# costFunction, regularization value 0.9465019383472545 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008880885931296564
# costFunction, regularization value 0.9429117902991915 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008852552622163723
# costFunction, regularization value 0.9393381898179508 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008835722362357155
# costFunction, regularization value 0.9358086572030425 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008803240510701797
# costFunction, regularization value 0.9322858722220742 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.00876740576020642
# costFunction, regularization value 0.9287152802125439 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008742996118652889
# costFunction, regularization value 0.9252097387664433 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008716177583172318
# costFunction, regularization value 0.9217342407324358 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008691994595493292
# costFunction, regularization value 0.9182451507213576 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008672389542246327
# costFunction, regularization value 0.914796280554137 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008655875332025997
# costFunction, regularization value 0.911363117930324 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008617806956479181
# costFunction, regularization value 0.9079363924077954 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008590623660798383
# costFunction, regularization value 0.9045144235376865 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.00857454114820549
# costFunction, regularization value 0.901145696345989 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.00854776211751797
# costFunction, regularization value 0.8977963472711582 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008527709457909163
# costFunction, regularization value 0.8944528545276513 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008512933386238725
# costFunction, regularization value 0.891129142959474 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008491190531473392
# costFunction, regularization value 0.8878597494355775 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008471697961937776
# costFunction, regularization value 0.8845702918442155 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008450846632558408
# costFunction, regularization value 0.8813238947901343 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.00843283262330381
# costFunction, regularization value 0.8779996235664317 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.00841135015335978
# costFunction, regularization value 0.874818845845756 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008393828841336595
# costFunction, regularization value 0.8715837765404749 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008377409211295952
# costFunction, regularization value 0.8684051198196806 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.00836004201096615
# costFunction, regularization value 0.8652202424336111 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008345259474676743
# costFunction, regularization value 0.8620907474563725 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008329238215607836
# costFunction, regularization value 0.8590347143783718 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.00831757594096298
# costFunction, regularization value 0.8559131265604281 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008301477468846673
# costFunction, regularization value 0.8527688925553724 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008295202227477792
# costFunction, regularization value 0.8497149464840225 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008275193599749214
# costFunction, regularization value 0.8466491444479596 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008258932921405584
# costFunction, regularization value 0.8436268765756629 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.00825479871783368
# costFunction, regularization value 0.8405996768859237 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008254300416638927
# costFunction, regularization value 0.8376272228186018 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008224889067233688
# costFunction, regularization value 0.8346429543973582 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008222155300747831
# costFunction, regularization value 0.8317442893170417 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008216545436183111
# costFunction, regularization value 0.8287934982141774 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008214550500806755
# costFunction, regularization value 0.8258836397386571 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008208764514983393
# costFunction, regularization value 0.8230273856939893 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008208958520063642
# costFunction, regularization value 0.8201545841466257 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008200160386778467
# costFunction, regularization value 0.8173321043752202 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008187591767847361
# costFunction, regularization value 0.8145005045691166 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.00819011098826656
# costFunction, regularization value 0.8116992430380652 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008195671163465446
# costFunction, regularization value 0.8089761768932882 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008198283017405893
# costFunction, regularization value 0.8062342027399556 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008211069011296628
# costFunction, regularization value 0.8035046662013706 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008193863428300968
# costFunction, regularization value 0.8008563254581712 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008197166048900636
# costFunction, regularization value 0.7981780030030833 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.0082075541842236
# costFunction, regularization value 0.7955541835215473 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.0082323688966322
# costFunction, regularization value 0.7930149876379838 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008273433151870744
# costFunction, regularization value 0.7904993436144365 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008267260391822673
# costFunction, regularization value 0.7879095378285883 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008275831319606347
# costFunction, regularization value 0.7853269701526117 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008288612286165922
# costFunction, regularization value 0.7828320896583834 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008292967606240194
# costFunction, regularization value 0.7804061200192888 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008339078370966192
# costFunction, regularization value 0.7781167582872125 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008359249255960438
# costFunction, regularization value 0.7756423235297403 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008377879201732184
# costFunction, regularization value 0.7732643272586529 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.00840566990195043
# costFunction, regularization value 0.7709063308377728 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008431471859662608
# costFunction, regularization value 0.7685648778593317 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008462521095622573
# costFunction, regularization value 0.7662859498657774 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008494317148359578
# costFunction, regularization value 0.7640125556900724 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008532104466346193
# costFunction, regularization value 0.761904729745696 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008571140476379368
# costFunction, regularization value 0.7597659415976583 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008607130308915783
# costFunction, regularization value 0.7576401483759218 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008633985913580455
# costFunction, regularization value 0.7555340381458648 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008686558622229147
# costFunction, regularization value 0.7536257419856615 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008749620984442529
# costFunction, regularization value 0.7515942994748694 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008788042684964536
# costFunction, regularization value 0.7496058431438721 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.00883313674740981
# costFunction, regularization value 0.7476348432087421 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008879700763507234
# costFunction, regularization value 0.7457280492566567 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.008939633242048606
# costFunction, regularization value 0.7439120417897017 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009022899833429856
# costFunction, regularization value 0.7421872672743228 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009103552684617426
# costFunction, regularization value 0.7404556018844205 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009170805400413817
# costFunction, regularization value 0.7388068666818354 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009252311657394024
# costFunction, regularization value 0.7372211545604765 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009327600990548742
# costFunction, regularization value 0.7354596567553942 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009438810157737457
# costFunction, regularization value 0.7339668053023013 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009480495083074567
# costFunction, regularization value 0.7324245653188546 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.00958329194784386
# costFunction, regularization value 0.7309914932189641 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009665645346251566
# costFunction, regularization value 0.7294677672493205 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.00975570764137776
# costFunction, regularization value 0.7281215331337353 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009827630022712568
# costFunction, regularization value 0.7266742136222571 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.009919533509370734
# costFunction, regularization value 0.7254536735789624 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.01000628230449334
# costFunction, regularization value 0.7241428527631327 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.010142676649456984
# costFunction, regularization value 0.7229813470940043 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.01019729987146396
# costFunction, regularization value 0.7216624851996185 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.010292469810315622
# costFunction, regularization value 0.7204988692054748 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.010408484087530053
# costFunction, regularization value 0.7193639533116158 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.010509876811328308
# costFunction, regularization value 0.7183380308512601 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.010614376698565828
# costFunction, regularization value 0.7174382118808817 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.01076618388764744
# costFunction, regularization value 0.7165592568086986 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.010824347837700428
# costFunction, regularization value 0.7155524314926923 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.010931642041835107
# costFunction, regularization value 0.7148214193959911 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.01109006045472412
# costFunction, regularization value 0.7140511123009651 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# ...
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.025199512255175086
# costFunction, regularization value 0.47838491639334074 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.025178756803606806
# costFunction, regularization value 0.47824614462944043 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.025086979878439046
# costFunction, regularization value 0.47820208332510616 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.025091605294268335
# costFunction, regularization value 0.47799201494283805 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.025111005915779628
# costFunction, regularization value 0.4776201108077995 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.025084529451032338
# costFunction, regularization value 0.4773703941746422 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.025109204365869147
# costFunction, regularization value 0.477464701642225 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.025061093581408907
# costFunction, regularization value 0.4772960556308893 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.02505682507040364
# costFunction, regularization value 0.47707643659268906 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.025071018480166317
# costFunction, regularization value 0.47691008174114563 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024969069264588063
# costFunction, regularization value 0.47650634033789996 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024977375870577696
# costFunction, regularization value 0.4766199476648014 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024944246649960297
# costFunction, regularization value 0.4763831943214484 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# LR = 0.5:  30%|█████████████████████▉                                                   | 3/10 [00:19<00:44,  6.41s/it]
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.02499240873049306
# costFunction, regularization value 0.47649593684902847 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.06636911648157535
# costFunction, regularization value 1.2708165533586198 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (96, 10) a3 (96, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (96, 64) a2 (96, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (96, 128) a1 (96, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.02471431382262368
# costFunction, regularization value 0.4735127327797365 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024764166233604362
# costFunction, regularization value 0.47325733051229313 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024717694155593932
# costFunction, regularization value 0.4732307774234396 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024789378979589438
# costFunction, regularization value 0.4733310004670452 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024730814646454487
# costFunction, regularization value 0.47289998507948494 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.02474812728213776
# costFunction, regularization value 0.4725943081539452 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024839972269652084
# costFunction, regularization value 0.4725863211415737 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024808645652705054
# costFunction, regularization value 0.472273847390563 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.02476211200624356
# costFunction, regularization value 0.4723062110953328 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024810770664716424
# costFunction, regularization value 0.47203097606428496 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.02477661238136234
# costFunction, regularization value 0.4716913511891176 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024839510411394802
# costFunction, regularization value 0.4716331766859144 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024873038264196214
# costFunction, regularization value 0.4711047725269991 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024816123983118395
# costFunction, regularization value 0.4710838062010474 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024870949811077455
# costFunction, regularization value 0.4710891620297284 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.02492588052882727
# costFunction, regularization value 0.470883813978078 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024875312740166838
# costFunction, regularization value 0.4707566408646626 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024868733003590698
# costFunction, regularization value 0.4708196294802486 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.02483043384325093
# costFunction, regularization value 0.47075036822123123 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024796307737919965
# costFunction, regularization value 0.47057763179737216 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.02479484362083629
# costFunction, regularization value 0.47038784672816714 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024814610277193984
# costFunction, regularization value 0.4701793285890926 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024881582370585853
# costFunction, regularization value 0.47035469532470175 , with lambda 1.0
# Calculating grad2  3
# Grad 3 shapes delta4 (256, 10) a3 (256, 65) ,theta 3(10, 64), grad shape (10, 65)
# Calculating grad2  2
# Grad 2 shapes delta3 (256, 64) a2 (256, 129) ,theta 2(64, 128), grad shape (64, 129)
# Calculating grad2  1
# Grad 1 shapes delta2 (256, 128) a1 (256, 785) ,theta 1(128, 784), grad shape (128, 785)
# 0.024857341229771176
